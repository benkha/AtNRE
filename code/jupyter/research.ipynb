# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
with open('code/jupyter/nyt_pcnn_pos_adv_eval_stats_ep30.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
with open('code/jupyter/nyt_bagrnn_adv_eval_stats_ep10.pkl', 'rb') as f:
    data_2 = pickle.load(f)

# %%
with open('code/jupyter/nyt_pcnn_sent_adv_4_eval_stats_ep26.pkl', 'rb') as f:
    data_3 = pickle.load(f)

# %%
precis, recall, f1_score = data

# %%
precis_2, recall_2, f1_score_2 = data_2

# %%
precis_3, recall_3, f1_score_3 = data_3

# %%
len(precis_3), len(recall_3)
# Out:
# (979, 979)

# %%
plt.plot(recall, precis, label='PCNN_ADV Position')
plt.plot(recall_2, precis_2, label='RNN_ADV Position')
plt.plot(recall_3, precis_3, label='PCNN_ADV Sentence')
plt.legend()
